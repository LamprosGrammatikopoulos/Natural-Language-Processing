# %% [markdown]
# # Deployment Endpoint Runner
# Run the cell below to start the Gradio UI.
#
# ### What to Expect
# After running the cell, these features will be made available:
# 1. **A local URL:** This URL will deactivate after a set amount of time. Re-run the cell to create a new URL.
# 2. **An embedded UI window:** Interactable without opeining a new tab.
# 3. **Real time logs:** Details on the model data will be outputted for every run.

# %%
import sys
import os
from pathlib import Path
from gradio_endpoint_UI import launch_ui

# Set up the path to include the project root and current directory
current_dir = Path(os.getcwd())
project_root = current_dir.parent

# Add both to sys.path to ensure modules can be imported
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))
if str(current_dir) not in sys.path:
    sys.path.append(str(current_dir))

# Import and Launch the Gradio UI
launch_ui()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
#
# Could not create share link. Please check your internet connection or our status page: https://status.gradio.app.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
