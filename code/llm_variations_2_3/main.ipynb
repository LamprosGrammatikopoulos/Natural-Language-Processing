# %% [markdown]
# # Q2.3 Multi-Variety Sarcasm Detection Pipeline with LoRA vs Full Fine-Tuning
#
# This is the main entry point (`main.ipynb`) for the sarcasm detection pipeline across different English varieties.
#
# The codebase has been highly modularized into the `utils/` directory to share configuration, data loading, tokenization, training, and evaluation logic cleanly across the distinct model architectures.
#
# ## Execution
#
# This notebook acts as the master orchestrator, executing the individual configuration notebooks for each architecture sequentially. All checkpoints and results will be saved into the configured `results/` directory.

# %% [markdown]
# ### TinyLlama-1.1B/Qwen2.5-1.5B/XLM-RoBERTa LoRA Adapters and XLM-RoBERTa Full Fine-Tuning

# %%
CONFIG_NAMES = ['tinyllama_lora', 'qwen25_lora', 'xlmr', 'xlmr_lora'] # Choose which ones to run
# %run -i utils/models.ipynb
# Out:
# [models.ipynb] Running configs: ['tinyllama_lora', 'qwen25_lora', 'xlmr', 'xlmr_lora']
#
#
# ...
# Starting Pipeline: tinyllama_lora
# ...
#
# Device : cuda
# GPU    : NVIDIA GeForce RTX 5070 Ti Laptop GPU
# Memory : 12.8 GB
#
# Starting Data Loading & Preparation
# ...
#   Splits   : ['train', 'validation', 'test']
#   Columns  : ['text', 'variety', 'source', 'Sentiment', 'Sarcasm']
#   Total train rows: 3747
#
#   Text column  : 'text'
#   Label column : 'Sarcasm'
#   Variety col  : 'variety'
#   en-AU | train       :  1145 rows
#   en-AU | validation  :    95 rows
#   en-AU | test        :   667 rows
#
#   en-UK | train       :  1203 rows
#   en-UK | validation  :   101 rows
#   en-UK | test        :   700 rows
#
#   en-IN | train       :  1399 rows
#   en-IN | validation  :   117 rows
#   en-IN | test        :   816 rows
#
# Preparing data for all varieties:
#   [en-AU] Training limited to 800 samples
#   [en-AU] Train (balanced)    : N=926  Sarc=463  Non-Sarc=463
# ...

# %%
# 11. Final Comprehensive Analysis
# Generate cross-architecture plots and metrics spanning the previous executed domains.
# %run utils/final_analysis.ipynb
